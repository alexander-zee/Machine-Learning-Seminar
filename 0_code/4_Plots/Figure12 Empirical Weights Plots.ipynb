feat2 = 3
feat3 = 4

feats = [feats_list[feat1], feats_list[feat2], feats_list[feat3]]
print(feats)

plot_out = "../../Data/plot/Heatmaps/tree_SDF_weights/" + "_".join(feats)
if not os.path.exists("../../Data/plot/Heatmaps/tree_SDF_weights/"):
    os.mkdir("../../Data/plot/Heatmaps/tree_SDF_weights/")
if not os.path.exists(plot_out):
    os.mkdir(plot_out)

data = np.array(pd.read_csv("../../Data/TreeGridSearch/"+"_".join(feats)+"/Selected_Ports_Weights_" + str(p) + ".csv",header=0))
print(data)
ports = pd.read_csv("../../Data/TreeGridSearch/"+"_".join(feats)+"/Selected_Ports_" + str(p) + ".csv",header=0).columns

matches = [headers.index(ports[i]) for i in range(p)]

feats_min = [np.array(pd.read_csv("../../Data/tree_portfolio_quantile/"+"_".join(feats)+"/level_all_"+feat+"_min_filtered.csv",header=0))[:,matches] for feat in feats]
feats_max = [np.array(pd.read_csv("../../Data/tree_portfolio_quantile/"+"_".join(feats)+"/level_all_"+feat+"_max_filtered.csv",header=0))[:,matches] for feat in feats]


grid=51

x = np.linspace(0, 1, grid)
y = np.linspace(0, 1, grid)
zs = np.linspace(0.1, 0.9, 4)
v = np.zeros((len(y), len(x), len(zs)))

t=0
for i in range(grid):
    for j in range(grid):
        for l in range(4):
            for k in range(p):
                if (x[j]>= feats_min[0][t,k] and x[j]<= feats_max[0][t,k] and y[i]>= feats_min[1][t,k] and y[i]<= feats_max[1][t,k] and zs[l]>= feats_min[2][t,k] and zs[l]<= feats_max[2][t,k]):
                    v[i, j, l] += data[k]

v_max = np.max(abs(v))
print(v_max)

x, y = np.meshgrid(x, y)

fig = plt.figure(figsize=(15,10))
ax = fig.gca(projection='3d')

levels = np.linspace(-1, 1, nlev)


for kk in range(len(zs)):
    z = zs[kk]
    im = ax.contourf(x, y, v[:,:,kk], offset=z, cmap=cmap, levels=levels)
ax.set_xlabel(feats[0])
ax.set_ylabel(feats[1])
ax.set_zlabel(feats[2])
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_zlim(0, 1)
cbar = plt.colorbar(im)
cbar.ax.set_ylabel('Weights')


plt.savefig(os.path.join(plot_out, "_".join(feats) + '.png'), dpi=300)
plt.clf()
plt.close()
# Out:
# ['LME', 'OP', 'Investment']
# [[ 1.05198482]
#  [ 0.13624767]
#  [ 0.09749369]
#  [ 0.20438897]
#  [-0.02392157]
#  [ 0.70151175]
#  [-0.64521066]
#  [-0.8200719 ]
#  [ 0.13163627]
#  [ 0.16594095]]
# 2.1870155025756777
# <ipython-input-15-26ff5ad5aaa4>:49: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
plot_out = "../../Data/plot/Heatmaps/ts_SDF_weights"
if not os.path.exists(plot_out):
    os.mkdir(plot_out)

grid = 4        
fine_grid = 100
t=0
 
ports = ["111","112","113","114","121","122","123","124","131","132","133","134","141",
  "142","143","144","211","212","213","214","221","222","223","224","231","232",
  "233","234","241","242","243","244"]

feat1 = 0
feat2 = 3
feat3 = 4

feats = [feats_list[feat1], feats_list[feat2], feats_list[feat3]]
print(feats)
    
data = np.array(pd.read_csv("../../Data/TSGridSearch/"+"_".join(feats)+"/Selected_Ports_Weights_32.csv",header=0))

x = np.linspace(0, 1, 2* fine_grid)
y = np.linspace(0, 1, grid * fine_grid)
zs = np.linspace(0.1, 0.9, 4)
v = np.zeros((len(y), len(x), len(zs)))

for port in range(32):
    i = int(str(ports[port])[1]) - 1
    j = int(str(ports[port])[0]) - 1
    k = int(str(ports[port])[2]) - 1
    v[(fine_grid*i):(fine_grid*i+fine_grid), (fine_grid*j):(fine_grid*j+fine_grid), k] = data[port]
v /= np.max(abs(v))

x, y = np.meshgrid(x, y)

fig = plt.figure(figsize=(15,10))
ax = fig.gca(projection='3d')

levels = np.linspace(-1, 1, nlev)


for k in range(len(zs)):
    z = zs[k]
    im = ax.contourf(x, y, v[:,:,k], offset=z, cmap=cmap, levels=levels)
ax.set_xlabel(feats[0])
ax.set_ylabel(feats[1])
ax.set_zlabel(feats[2])
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_zlim(0, 1)
cbar = plt.colorbar(im)
cbar.ax.set_ylabel('Weights')

plt.savefig(os.path.join(plot_out, "_".join(feats) + '.png'), dpi=300)
plt.clf()
# Out:
# ['LME', 'OP', 'Investment']
# <ipython-input-19-6b8c83a2b642>:37: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
plt.rcParams.update({'font.size': 18, 'axes.labelweight': 'bold', 'axes.labelsize': 20})
plot_out = "../../Data/plot/Heatmaps/ts64_SDF_weights"
if not os.path.exists(plot_out):
    os.mkdir(plot_out)

grid = 4        
fine_grid = 100
t=0
 
ports = ["111","112","113","114","121","122","123","124","131",
             "132","133","134","141","142","143","144",
             "211","212","213","214","221","222","223","224","231",
             "232","233","234","241","242","243","244",
             "311","312","313","314","321","322","323","324","331",
             "332","333","334","341","342","343","344",
             "411","412","413","414","421","422","423","424","431",
             "432","433","434","441","442","443","444"]

feat1 = 0
feat2 = 3
feat3 = 4
feats = [feats_list[feat1], feats_list[feat2], feats_list[feat3]]
print(feats)

data = np.array(pd.read_csv("../../Data/TS64GridSearch/"+"_".join(feats)+"/Selected_Ports_Weights_64.csv",header=0))

x = np.linspace(0, 1, grid * fine_grid)
y = np.linspace(0, 1, grid * fine_grid)
zs = np.linspace(0.1, 0.9, 4)
v = np.zeros((len(y), len(x), len(zs)))

for port in range(64):
    i = int(str(ports[port])[1]) - 1
    j = int(str(ports[port])[0]) - 1
    k = int(str(ports[port])[2]) - 1
    v[(fine_grid*i):(fine_grid*i+fine_grid), (fine_grid*j):(fine_grid*j+fine_grid), k] = data[port]
v /= np.max(abs(v))

x, y = np.meshgrid(x, y)

fig = plt.figure(figsize=(15,10))
ax = fig.gca(projection='3d')

levels = np.linspace(-1, 1, nlev)


for k in range(len(zs)):
    z = zs[k]
    im = ax.contourf(x, y, v[:,:,k], offset=z, cmap=cmap, levels=levels)
ax.set_xlabel(feats[0])
ax.set_ylabel(feats[1])
ax.set_zlabel(feats[2])
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_zlim(0, 1)
cbar = plt.colorbar(im)
cbar.ax.set_ylabel('Weights')

plt.savefig(os.path.join(plot_out, "_".join(feats) + '.png'), dpi=300)
plt.clf()
# Out:
# ['LME', 'OP', 'Investment']
# <ipython-input-21-6979f960e23a>:42: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
